# %% [markdown]
# <a href="https://colab.research.google.com/github/basimgazim/googleColab/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## دالة لحساب المضروب (Factorial Function)

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
